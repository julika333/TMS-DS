# %% [markdown]
# <a href="https://colab.research.google.com/github/julika333/TMS-DS/blob/main/lesson_13_terver/HW_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.special import perm, factorial, comb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 1000
d = 5
p = d/n
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.005

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
r = 9
y = 6
g = 5

p = y / (r + y + g)
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 16
n_port = 4
p = n_port / n
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 8
m = 6

p = m / n
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.75

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 16
n_angl = 4

p = 1 - n_angl/n
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.75

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 21
k = 3
# Аню можно исключить и сразу считать верятность для Нины с учетом, что осталось 20 человек и 2 месят в ту же группу, где и Аня
p = (3-1)/(21-1)
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# c 7 До 1 ровно 6 часов, т.е половина
p = 6/12
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# c 6 До 9 ровно 3 часа
p = 3/12
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 4 # всего исходов
b = 2 # орел выадет один раз (либо за первый бросо, либо за второй)
p = b/n
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p = 1/2 * 1/2
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p_err = 0.19
p = 1- p_err
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.81

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p = 1- 0.965
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.03500000000000003

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p_u = 0.1
p_p = 0.6
p = 0.1+0.6
print(f"c вероятностью: {p}")
# Out:
# c вероятностью: 0.7
